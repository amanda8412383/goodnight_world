# %%
from google.cloud import bigquery
import os
import tweepy
import pandas as pd
import numpy as np
import csv
from tweepy import OAuthHandler
from datetime import datetime
from datetime import timedelta
import import_ipynb
import twitterkey

os.environ["GOOGLE_APPLICATION_CREDENTIALS"]=r'RA_WORK_CONTENT_BQ.json'

# %%
# Out:
# importing Jupyter notebook from twitterkey.ipynb

# %%
# consumer_key = '3H70QQ9AzguYY5KWXmHPO9Qzi'
# consumer_secret = 'J7Pr45oEcpHHosdnQyOytHf8Sn30cZowc5bUyIBhwZTboQeh8W'
# access_token = '991551756889870341-VtFhYuXuggtMNRAg26bVykdoy7Xi6mV'
# access_secret = 'hbtF96dFDxQcNATEtnBOkT5iVNfUK7BcWnGKHktd6W9gZ'
auth = OAuthHandler( twitterkey.consumer_key, twitterkey.consumer_secret)
auth.set_access_token(twitterkey.access_token, twitterkey.access_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %% [markdown]
# ### 2017

# %%
ceo_tweet_2017 = pd.read_csv(r'CEO_2017.csv', engine = "python", index_col=False, skiprows = 1, 
    encoding ="ISO-8859-1", header=None, na_values = '-')
ceo_tweet_2017.columns  = ['CO_PER_ROL',  'YEAR', 'EXEC_FULLNAME', 'T_NAME']
ceo_tweet_2017['CO_PER_ROL'].nunique() == ceo_tweet_2017['CO_PER_ROL'].count()



ceo_tweet_2017.head()
# ceo_tweet_2017[ceo_tweet_2017.EXEC_FULLNAME.isna()]
# Out:
#    CO_PER_ROL  YEAR          EXEC_FULLNAME        T_NAME
# 0       38455  2017   Norman H. Asbjornson             X
# 1       51946  2017       Scott B. Salmirs             X
# 2        2653  2017       Daniel Paul Amos             X
# 3       28867  2017  Martin H. Richenhagen             X
# 4       37514  2017  James M. Moroney, III  jmoroney_jim

# %%
#CHECK MISSING VALUE
see = ceo_tweet_2017[ceo_tweet_2017.T_NAME.isna()]
see

#COUNT RATIO 
ceo_tweet_2017[['T_NAME']] = ceo_tweet_2017[['T_NAME']].fillna(value='X')
ceo_tweet_2017 = ceo_tweet_2017.drop_duplicates()


#count = ceo_tweet_2017[ceo_tweet_2017.T_NAME == 'X'].value_counts()


# find = ceo_tweet_2017.loc[ceo_tweet_2017['T_NAME'] != 'X']['T_NAME'].count()
find2= len (ceo_tweet_2017.loc[ceo_tweet_2017['T_NAME'] != 'X'].index)

# miss = ceo_tweet_2017.loc[ceo_tweet_2017['T_NAME'] == '7']['T_NAME'].count()
miss2= len (ceo_tweet_2017.loc[ceo_tweet_2017['T_NAME'] == 'X'].index)

ratio = find2/miss2 * 100 

#eo_tweet_2017.loc[ceo_tweet_2017['T_NAME'] == '7']
ratio
# Out:
# 17.134416543574595

# %% [markdown]
# ### OTHER YEAR

# %%
ceo_201x = pd.read_csv(r'CEO_201X.csv', engine = "python", index_col=False, skiprows = 1, 
    encoding ="ISO-8859-1", header=None, na_values = '-')

ceo_201x = ceo_201x.iloc[:, 0:13]
ceo_201x.columns  = ['CO_PER_ROL', 'CUSIP', 'CONAME', 'EXEC_FNAME','EXEC_FULLNAME', 'EXEC_LNAME','YEAR', 'TWITTER', 'T_NAME', 'Search Date', 'company related', 'personal related', 'Note']

ceo_tweet_201x = ceo_201x.filter(items=['CO_PER_ROL', 'EXEC_FULLNAME', 'YEAR', 'T_NAME'])
ceo_tweet_201x['T_NAME'].fillna(value='X', inplace=True)
#CHECK
#ceo_tweet_201x.loc[ceo_tweet_201x['T_NAME'].isna(), ]
ceo_tweet_2014_6 = ceo_tweet_201x.loc[ceo_tweet_201x['YEAR'] > 2013]

ceo_tweet_2014_6.head()
# Out:
#     CO_PER_ROL          EXEC_FULLNAME  YEAR         T_NAME
# 10       35453     Aaron D. Todd, III  2016              X
# 12       45435  Abraham N. Reichental  2015  AviReichental
# 14       38633         Adam D. Singer  2014              X
# 16       39639      Adolphus B. Baker  2016              X
# 18       39584       Ahmad R. Chatila  2014  AhmadRChatila

# %%
# #SELECT YEAR
# ceo_tweet_201X = ceo_tweet_201x.loc[ceo_tweet_201x['YEAR'] == 2014]
# #CHECK MISSING VALUE
# # see = ceo_tweet_201X[ceo_tweet_201X.T_NAME.isna()]
# # see

# #COUNT RATIO 
# ceo_tweet_201X = ceo_tweet_201X.drop_duplicates()


# #count = ceo_tweet_201X[ceo_tweet_201X.T_NAME == 'X'].value_counts()


# # find = ceo_tweet_201X.loc[ceo_tweet_201X['T_NAME'] != 'X']['T_NAME'].count()
# find2= len (ceo_tweet_201X.loc[ceo_tweet_201X['T_NAME'] != 'X'].index)

# # miss = ceo_tweet_201X.loc[ceo_tweet_201X['T_NAME'] == 'X']['T_NAME'].count()
# miss2= len (ceo_tweet_201X.loc[ceo_tweet_201X['T_NAME'] == 'X'].index)

# ratio = find2/miss2 * 100

# #eo_tweet_201X.loc[ceo_tweet_201X['T_NAME'] == 'X']
# ratio

# %% [markdown]
# ## merge 2017 with other years

# %%
ceo = pd.merge(ceo_tweet_2014_6, ceo_tweet_2017, how='outer')

ceo.head()
# Out:
#    CO_PER_ROL          EXEC_FULLNAME  YEAR         T_NAME
# 0       35453     Aaron D. Todd, III  2016              X
# 1       45435  Abraham N. Reichental  2015  AviReichental
# 2       38633         Adam D. Singer  2014              X
# 3       39639      Adolphus B. Baker  2016              X
# 4       39584       Ahmad R. Chatila  2014  AhmadRChatila

# %% [markdown]
# ### clean t_name for capture

# %%
ceo = ceo[ceo.T_NAME != 'X']
ceo = ceo[ceo.T_NAME != 'x']

#clean wired things x]
ceo[~ceo['T_NAME'].str.contains("]", regex=False) ]

ceo_duplicated = ceo.duplicated(subset = ['T_NAME', 'EXEC_FULLNAME', ])


ceo.loc[ceo_duplicated]
# ceo[ceo.EXEC_FULLNAME.isna()]
# Out:
#       CO_PER_ROL             EXEC_FULLNAME  YEAR         T_NAME
# 1688       51789  Margaret Cushing Whitman  2017     MegWhitman
# 1727       59445            Paul M. Bisaro  2017     PaulBisaro
# 2421       51968          Peter A. Altabef  2017       PAltabef
# 2496       59618         Mindy F. Grossman  2017  mindygrossman

# %% [markdown]
# ### def store function

# %%
def implicit():
    from google.cloud import storage
    storage_client = storage.Client()
    buckets = list(storage_client.list_buckets())
    print(buckets)

client = bigquery.Client()
dataset_id = 'ceo_tweet_streaming'  
table_id = 'search_2017_14_backup' 

table_ref = client.dataset(dataset_id).table(table_id)
table = client.get_table(table_ref) 


def store_data(	name, id_str, status_id,  CO_PER_ROL, YEAR, EXEC_FULLNAME, created_at, fulltext, truncated, reply_to_status_id, reply_to_name,reply_to_user_id, is_quote, retweet_cnt, favorite_cnt, is_retweet):
    rows_to_insert = [(name, id_str, status_id, CO_PER_ROL, YEAR, EXEC_FULLNAME,  created_at, fulltext, truncated, reply_to_status_id, reply_to_name,reply_to_user_id, is_quote, retweet_cnt, favorite_cnt, is_retweet, 3), ]
    errors = client.insert_rows(table, rows_to_insert)


    print(errors, 'bq')
    assert errors == []
    return

# %%
ceo1 = ceo[0:100]
ceo2 = ceo[100:200]
ceo3 = ceo[200:300]
ceo4 = ceo[300: ]

# %% [markdown]
# ### search

# %%
ceo_cnt = 0
fail = 0
cnt = 0

for row in ceo1.itertuples():
    name = row.T_NAME
    ceo_cnt += 1



    try:
        tweet = tweepy.Cursor(api.user_timeline, screen_name=name, tweet_mode='extended', wait_on_rate_limit =True, wait_on_rate_limit_notify=True).items()

        if tweet == []:
            continue
            
        else: 
            for line in tweet:
                cnt += 1
                is_retweet = False
                full_text = line.full_text
                clean_timestamp = line.created_at
                if hasattr(line, 'retweeted_status'):
                    is_retweet = True
                    full_text = line.retweeted_status.full_text 
                store_data(name, line.user.id, line.id, row.CO_PER_ROL, row.YEAR, row.EXEC_FULLNAME, clean_timestamp, full_text, line.truncated, line.in_reply_to_status_id, line.in_reply_to_screen_name, line.in_reply_to_user_id, line.is_quote_status, line.retweet_count, line.favorite_count, is_retweet)
    except tweepy.TweepError:
        fail += 1
        
print('search ceo :' + str(ceo_cnt))
print('search fail :' + str(fail))
print('return search result :' + str(cnt))
# Out:
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# ...

# %%
ceo_cnt = 0
fail = 0
cnt = 0

for row in ceo2.itertuples():
    name = row.T_NAME
    ceo_cnt += 1



    try:
        tweet = tweepy.Cursor(api.user_timeline, screen_name=name, tweet_mode='extended', wait_on_rate_limit =True, wait_on_rate_limit_notify=True).items()

        if tweet == []:
            continue
            
        else: 
            for line in tweet:
                cnt += 1
                is_retweet = False
                full_text = line.full_text
                clean_timestamp = line.created_at
                if hasattr(line, 'retweeted_status'):
                    is_retweet = True
                    full_text = line.retweeted_status.full_text 
                store_data(name, line.user.id, line.id, row.CO_PER_ROL, row.YEAR, row.EXEC_FULLNAME, clean_timestamp, full_text, line.truncated, line.in_reply_to_status_id, line.in_reply_to_screen_name, line.in_reply_to_user_id, line.is_quote_status, line.retweet_count, line.favorite_count, is_retweet)
    except tweepy.TweepError:
        fail += 1
        
print('search ceo :' + str(ceo_cnt))
print('search fail :' + str(fail))
print('return search result :' + str(cnt))
# Out:
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# ...

# %%
ceo_cnt = 0
fail = 0
cnt = 0

for row in ceo3.itertuples():
    name = row.T_NAME
    ceo_cnt += 1



    try:
        tweet = tweepy.Cursor(api.user_timeline, screen_name=name, tweet_mode='extended', wait_on_rate_limit =True, wait_on_rate_limit_notify=True).items()

        if tweet == []:
            continue
            
        else: 
            for line in tweet:
                cnt += 1
                is_retweet = False
                full_text = line.full_text
                clean_timestamp = line.created_at
                if hasattr(line, 'retweeted_status'):
                    is_retweet = True
                    full_text = line.retweeted_status.full_text 
                store_data(name, line.user.id, line.id, row.CO_PER_ROL, row.YEAR, row.EXEC_FULLNAME, clean_timestamp, full_text, line.truncated, line.in_reply_to_status_id, line.in_reply_to_screen_name, line.in_reply_to_user_id, line.is_quote_status, line.retweet_count, line.favorite_count, is_retweet)
    except tweepy.TweepError:
        fail += 1
        
print('search ceo :' + str(ceo_cnt))
print('search fail :' + str(fail))
print('return search result :' + str(cnt))
# Out:
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# ...

# %%
ceo_cnt = 0
fail = 0
cnt = 0

for row in ceo4.itertuples():
    name = row.T_NAME
    ceo_cnt += 1



    try:
        tweet = tweepy.Cursor(api.user_timeline, screen_name=name, tweet_mode='extended', wait_on_rate_limit =True, wait_on_rate_limit_notify=True).items()

        if tweet == []:
            continue
            
        else: 
            for line in tweet:
                cnt += 1
                is_retweet = False
                full_text = line.full_text
                clean_timestamp = line.created_at
                if hasattr(line, 'retweeted_status'):
                    is_retweet = True
                    full_text = line.retweeted_status.full_text 
                store_data(name, line.user.id, line.id, row.CO_PER_ROL, row.YEAR, row.EXEC_FULLNAME, clean_timestamp, full_text, line.truncated, line.in_reply_to_status_id, line.in_reply_to_screen_name, line.in_reply_to_user_id, line.is_quote_status, line.retweet_count, line.favorite_count, is_retweet)
    except tweepy.TweepError:
        fail += 1
        
print('search ceo :' + str(ceo_cnt))
print('search fail :' + str(fail))
print('return search result :' + str(cnt))
# Out:
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# [] bq
# ...

# %% [markdown]
# ### tb_id

# %%
file = open(r'tweet_id.csv', 'a', encoding="utf-8", newline='')
csvwriter = csv.writer(file)
csvwriter.writerow(['name', 'id_str', 'CO_PER_ROL', 'YEAR', 'EXEC_FULLNAME', 'followers_count', 'friends_count', 'lang', 'account_created'])

#key = id
tweetCount = 1
ceo_cnt = 0
tweet_cnt = 0
no_twitter_cnt = 0
fail = 0

for row in ceo.itertuples():
    name = row.T_NAME
    ceo_cnt += 1

    try:
        tweet = api.user_timeline(screen_name=name, count=tweetCount, wait_on_rate_limit_notify=True, wait_on_rate_limit=True)
        if tweet == []:
            no_twitter_cnt += 1
            continue
        else: 
            tweet_cnt += 1
            for line in tweet:
                csvwriter.writerow([name,"'" + str(line.user.id_str), row.CO_PER_ROL, row.YEAR, row.EXEC_FULLNAME, line.user.followers_count, line.user.friends_count, line.lang, line.user.created_at])
    except tweepy.TweepError:
        fail += 1

    # if tweet_cnt == 15:
        # break

print('search ceo :' + str(ceo_cnt))
print('search has no result :' + str(no_twitter_cnt))
print('return search result :' + str(tweet_cnt))


file.close()
# Out:
# search ceo :362
# search has no result :43
# return search result :290

# %% [markdown]
# # to do
# 3. check duplicate
