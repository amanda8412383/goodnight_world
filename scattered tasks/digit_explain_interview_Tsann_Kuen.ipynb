# %% [markdown]
# # DIGIT
# ### what is digit?
#
# ### let's start with looking at wikipedia

# %%
from IPython.display import HTML
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/Numerical_digit'
html = HTML(url)
display(html)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Numerical digit - Wikipedia</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# ...

# %% [markdown]
# # definition in a sentence
#
# ## A digit is an element of a set that, taken as a whole, comprises a system of numeration.
# 為一個組合的元素，用以構成數位系統
#
# # ASCII

# %%
' '.join(str(ord(x)) for x in 'Tsann Kuen')
# Out:
# '84 115 97 110 110 32 75 117 101 110'

# %% [markdown]
# # BINARY

# %%
' '.join(format(ord(x), 'b') for x in 'Tsann Kuen')
# Out:
# '1010100 1110011 1100001 1101110 1101110 100000 1001011 1110101 1100101 1101110'

# %% [markdown]
# # DATA
#
# ## bcs of access limitation, using data from google trend
# ## search number for past year

# %%
search = pd.read_csv('multiTimeline.csv')
search.head(10)
# Out:
#         week  times
# 0  2018/4/29     70
# 1   2018/5/6     69
# 2  2018/5/13     74
# 3  2018/5/20     71
# 4  2018/5/27     77
# 5   2018/6/3     63
# 6  2018/6/10     56
# 7  2018/6/17     55
# 8  2018/6/24     59
# 9   2018/7/1     64

# %% [markdown]
# # plot

# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt

# %%
search.plot(kind='line',x='week',y='times',color='blue')
plt.show()

# %% [markdown]
# # peak explain: 1111 sales event

# %%
search.loc[search['times'].idxmax()]
# Out:
# week     2018/11/11
# times           100
# Name: 28, dtype: object
